# %% [markdown]
# # 50_Startups

# %%
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-5c004ffe-48a7-41d1-93f2-6db194a14bc5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5c004ffe-48a7-41d1-93f2-6db194a14bc5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
startups=pd.read_csv('50_Startups.csv')
startups
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
startups=startups.rename({'R&D Spend':'RD_Spend'},axis=1)
startups=startups.rename({'Marketing Spend':'Marketing_Spend'},axis=1)
startups.head()
# Out:
#     RD_Spend  Administration  Marketing_Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
startups.duplicated().sum()
# Out:
# 0

# %%
startups.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RD_Spend         50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing_Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
startups_corr=startups.corr()
startups_corr
# Out:
#                  RD_Spend  Administration  Marketing_Spend    Profit
# RD_Spend         1.000000        0.241955         0.724248  0.972900
# Administration   0.241955        1.000000        -0.032154  0.200717
# Marketing_Spend  0.724248       -0.032154         1.000000  0.747766
# Profit           0.972900        0.200717         0.747766  1.000000

# %% [markdown]
# **EDA and Data Visualization**

# %%
import seaborn as sns

import matplotlib.pyplot as plt

# %%
sns.heatmap(startups_corr, annot=True, cmap='Blues')
# Out:
# <Axes: >

# %%
sns.pairplot(startups)

# %% [markdown]
# **Outlier detection in the target variable (Profit)**

# %%
sns.boxplot(data=startups['Profit'], orient='v')

plt.title('Outlier Distribution')
plt.ylabel('Profit Range')
plt.xlabel('Profit')

plt.show()

# %% [markdown]
# In the above boxplot, we can see that there is an outlier present in the target variable (Profit). But there are just 50 entries, so it won't create much negetive impact.

# %% [markdown]
# ***Model Developement***

# %%
startups['State'].unique()
# Out:
# array(['New York', 'California', 'Florida'], dtype=object)

# %%
startups= pd.get_dummies(startups, columns=['State'])
startups
# Out:
#      RD_Spend  Administration  Marketing_Spend     Profit  State_California  \
# 0   165349.20       136897.80        471784.10  192261.83                 0
# 1   162597.70       151377.59        443898.53  191792.06                 1
# 2   153441.51       101145.55        407934.54  191050.39                 0
# 3   144372.41       118671.85        383199.62  182901.99                 0
# 4   142107.34        91391.77        366168.42  166187.94                 0
# 5   131876.90        99814.71        362861.36  156991.12                 0
# 6   134615.46       147198.87        127716.82  156122.51                 1
# 7   130298.13       145530.06        323876.68  155752.60                 0
# 8   120542.52       148718.95        311613.29  152211.77                 0
# 9   123334.88       108679.17        304981.62  149759.96                 1
# 10  101913.08       110594.11        229160.95  146121.95                 0
# ...

# %%
startups=startups.rename({'State_New York':'State_New_York'},axis=1)

# %% [markdown]
# **Regression Model**

# %%
import statsmodels.formula.api as smf

import numpy as np

# %% [markdown]
# **1. No Transformation**

# %%
model=smf.ols('Profit~Administration+RD_Spend+Marketing_Spend+State_California+State_Florida+State_New_York', data=startups).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                     169.9
# Date:                Wed, 05 Jul 2023   Prob (F-statistic):           1.34e-27
# Time:                        17:48:51   Log-Likelihood:                -525.38
# No. Observations:                  50   AIC:                             1063.
# Df Residuals:                      44   BIC:                             1074.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %% [markdown]
# The R-squared value (95.1%) which is good and the model can be accepted. But however we can see that the variable 'Administration' and 	'Marketing_Spend' does not accept the p-value. The both are correlated. .

# %% [markdown]
# **Solving Multicollinearity**
#
# 1. High Influence Points

# %%
startups.shape
# Out:
# (50, 7)

# %%
from statsmodels.graphics.regressionplots import influence_plot
influence_plot(model)
plt.show()

# %% [markdown]
# 2. Cook's Distance

# %%
model_influence = model.get_influence()
(c, _) = model_influence.cooks_distance

# %%
fig = plt.subplots(figsize=(20, 8))
plt.stem(np.arange(len(startups)), np.round(c, 3))
plt.xlabel('Row index')
plt.ylabel('Cooks Distance')
plt.show()

# %% [markdown]
# From the above plot, we can see that data point **49** and **48** are the influencers.

# %% [markdown]
# **Improving the model**

# %%
startups[startups.index.isin([49,48])]
# Out:
#     RD_Spend  Administration  Marketing_Spend    Profit  State_California  \
# 48    542.05        51743.15             0.00  35673.41                 0
# 49      0.00       116983.80         45173.06  14681.40                 1
#
#     State_Florida  State_New_York
# 48              0               1
# 49              0               0

# %%
startups = startups.drop(startups.index[[49,48]])

# %% [markdown]
# **VIF (Variance Inflation Factor)**

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
df=startups.copy()

# %%
df.columns
# Out:
# Index(['RD_Spend', 'Administration', 'Marketing_Spend', 'Profit',
#        'State_California', 'State_Florida', 'State_New_York'],
#       dtype='object')

# %%
rsq_RD_Spend = smf.ols('RD_Spend~Administration+Marketing_Spend+State_California+State_Florida+State_New_York',data=df).fit().rsquared
vif_RD_Spend = 1/(1-rsq_RD_Spend)

rsq_Administration = smf.ols('Administration~RD_Spend+Marketing_Spend+State_California+State_Florida+State_New_York',data=df).fit().rsquared
vif_Administration = 1/(1-rsq_Administration)

rsq_Marketing_Spend = smf.ols('Marketing_Spend~RD_Spend+Administration+State_California+State_Florida+State_New_York',data=df).fit().rsquared
vif_Marketing_Spend = 1/(1-rsq_Marketing_Spend)

rsq_State_California = smf.ols('State_California~RD_Spend+Administration+Marketing_Spend+State_Florida+State_New_York',data=df).fit().rsquared
vif_State_California = 1/(1-rsq_State_California)

rsq_State_Florida = smf.ols('State_Florida~RD_Spend+Administration+Marketing_Spend+State_California+State_Florida',data=df).fit().rsquared
vif_State_Florida = 1/(1-rsq_State_Florida)

rsq_State_New_York = smf.ols('State_New_York~RD_Spend+Administration+Marketing_Spend+State_California+State_New_York',data=df).fit().rsquared
vif_State_New_York = 1/(1-rsq_State_New_York)

data={'Variables':['RD_Spend', 'Administration', 'Marketing_Spend','State_California', 'State_Florida', 'State_New_York'],'VIF':[vif_RD_Spend,vif_Administration,vif_Marketing_Spend,vif_State_California,vif_State_Florida,vif_State_New_York ]}
VIF_frame=pd.DataFrame(data)
VIF_frame
# Out:
#           Variables       VIF
# 0          RD_Spend  2.268965
# 1    Administration  1.202930
# 2   Marketing_Spend  2.305283
# 3  State_California       inf
# 4     State_Florida       inf
# 5    State_New_York       inf

# %%
X = df[['RD_Spend','Administration', 'Marketing_Spend', 'State_California', 'State_Florida', 'State_New_York']]
Y = df[['Profit']]

# %%
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["features"] = X.columns
vif.round(1)
# Out:
#    VIF Factor          features
# 0         2.3          RD_Spend
# 1         1.2    Administration
# 2         2.3   Marketing_Spend
# 3        10.5  State_California
# 4        11.6     State_Florida
# 5        11.5    State_New_York

# %% [markdown]
# Since 'Administration' variable has the lowest VIF, so we need to discard it to get a better model.

# %%
model_new=smf.ols('Profit~RD_Spend+Marketing_Spend+State_California+State_Florida+State_New_York',data=startups).fit()

# %%
model_new.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.961
# Model:                            OLS   Adj. R-squared:                  0.958
# Method:                 Least Squares   F-statistic:                     265.9
# Date:                Wed, 05 Jul 2023   Prob (F-statistic):           1.02e-29
# Time:                        17:48:53   Log-Likelihood:                -494.30
# No. Observations:                  48   AIC:                             998.6
# Df Residuals:                      43   BIC:                             1008.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %% [markdown]
# Test for Normality of Residuals (Q-Q Plot)

# %%
import statsmodels.api as sm
qqplot=sm.qqplot(model.resid,line='q')
plt.title("Normal Q-Q plot of residuals")
plt.show()

# %% [markdown]
# **Transformations**
#
# 1. Log transformation of Y

# %%
import numpy as np

# %%
x=startups[['RD_Spend','Marketing_Spend', 'State_California', 'State_Florida', 'State_New_York']]
y = np.log(startups[['Profit']])

# %%
model_1=smf.ols('y~x',data=startups).fit()

# %%
model_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.922
# Model:                            OLS   Adj. R-squared:                  0.915
# Method:                 Least Squares   F-statistic:                     127.7
# Date:                Wed, 05 Jul 2023   Prob (F-statistic):           2.87e-23
# Time:                        17:48:55   Log-Likelihood:                 45.640
# No. Observations:                  48   AIC:                            -81.28
# Df Residuals:                      43   BIC:                            -71.92
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      8.2765      0.024    345.161      0.000       8.228       8.325
# ...

# %% [markdown]
# 2. Square Root transformation of X

# %%
x=np.sqrt(startups[['RD_Spend','Marketing_Spend', 'State_California', 'State_Florida', 'State_New_York']])
y=startups[['Profit']]

# %%
model_2=smf.ols('y~x',data=startups).fit()

# %%
model_2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.887
# Model:                            OLS   Adj. R-squared:                  0.877
# Method:                 Least Squares   F-statistic:                     84.44
# Date:                Wed, 05 Jul 2023   Prob (F-statistic):           8.67e-20
# Time:                        17:48:55   Log-Likelihood:                -519.91
# No. Observations:                  48   AIC:                             1050.
# Df Residuals:                      43   BIC:                             1059.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.359e+04   4547.534      2.989      0.005    4419.598    2.28e+04
# ...

# %% [markdown]
# 3. Square Root transformation of Y

# %%
x=(startups[['RD_Spend','Marketing_Spend', 'State_California', 'State_Florida', 'State_New_York']])
y=np.sqrt(startups[['Profit']])

# %%
model_3=smf.ols('y~x',data=startups).fit()

# %%
model_3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.954
# Model:                            OLS   Adj. R-squared:                  0.950
# Method:                 Least Squares   F-statistic:                     223.3
# Date:                Wed, 05 Jul 2023   Prob (F-statistic):           3.68e-28
# Time:                        17:48:55   Log-Likelihood:                -185.87
# No. Observations:                  48   AIC:                             381.7
# Df Residuals:                      43   BIC:                             391.1
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    180.6811      2.982     60.597      0.000     174.668     186.694
# ...

# %% [markdown]
# 4. Square Root Transformation of both X and Y

# %%
x=np.sqrt(startups[['RD_Spend','Marketing_Spend', 'State_California', 'State_Florida', 'State_New_York']])
y=np.sqrt(startups[['Profit']])

# %%
model_4=smf.ols('y~x',data=startups).fit()

# %%
model_4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.929
# Model:                            OLS   Adj. R-squared:                  0.923
# Method:                 Least Squares   F-statistic:                     141.7
# Date:                Wed, 05 Jul 2023   Prob (F-statistic):           3.64e-24
# Time:                        17:48:55   Log-Likelihood:                -196.16
# No. Observations:                  48   AIC:                             402.3
# Df Residuals:                      43   BIC:                             411.7
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    141.1732      5.353     26.372      0.000     130.377     151.969
# ...

# %% [markdown]
# After looking through all the transformation, the **model_new** in which the variable 'Administration' is discarded, gives the best R-squatred value(96.1%)

# %% [markdown]
# # Toyota

# %%
import pandas as pd

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-f99bfcf9-a6f5-421c-99d7-fc636d6e6e08" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f99bfcf9-a6f5-421c-99d7-fc636d6e6e08">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
toyota=pd.read_csv('ToyotaCorolla.csv',encoding='latin1')

# %%
df=toyota[["Price","Age_08_04","KM","HP","cc","Doors","Gears","Quarterly_Tax","Weight"]]
df.head()
# Out:
#    Price  Age_08_04     KM  HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0  13500         23  46986  90  2000      3      5            210    1165
# 1  13750         23  72937  90  2000      3      5            210    1165
# 2  13950         24  41711  90  2000      3      5            210    1165
# 3  14950         26  48000  90  2000      3      5            210    1165
# 4  13750         30  38500  90  2000      3      5            210    1170

# %%
df=df.rename({'Age_08_04':'Age','cc':'CC'},axis=1)

# %%
df.shape
# Out:
# (1436, 9)

# %%
df[df.duplicated()]
# Out:
#      Price  Age     KM   HP    CC  Doors  Gears  Quarterly_Tax  Weight
# 113  24950    8  13253  116  2000      5      5            234    1320

# %%
df=df.drop_duplicates().reset_index(drop=True)
df.head()
# Out:
#    Price  Age     KM  HP    CC  Doors  Gears  Quarterly_Tax  Weight
# 0  13500   23  46986  90  2000      3      5            210    1165
# 1  13750   23  72937  90  2000      3      5            210    1165
# 2  13950   24  41711  90  2000      3      5            210    1165
# 3  14950   26  48000  90  2000      3      5            210    1165
# 4  13750   30  38500  90  2000      3      5            210    1170

# %%
df.shape
# Out:
# (1435, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1435 entries, 0 to 1434
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Price          1435 non-null   int64
#  1   Age            1435 non-null   int64
#  2   KM             1435 non-null   int64
#  3   HP             1435 non-null   int64
#  4   CC             1435 non-null   int64
#  5   Doors          1435 non-null   int64
#  6   Gears          1435 non-null   int64
#  7   Quarterly_Tax  1435 non-null   int64
#  8   Weight         1435 non-null   int64
# dtypes: int64(9)
# memory usage: 101.0 KB

# %%
df.corr()
# Out:
#                   Price       Age        KM        HP        CC     Doors  \
# Price          1.000000 -0.876273 -0.569420  0.314134  0.124375  0.183604
# Age           -0.876273  1.000000  0.504575 -0.155293 -0.096549 -0.146929
# KM            -0.569420  0.504575  1.000000 -0.332904  0.103822 -0.035193
# HP             0.314134 -0.155293 -0.332904  1.000000  0.035207  0.091803
# CC             0.124375 -0.096549  0.103822  0.035207  1.000000  0.079254
# Doors          0.183604 -0.146929 -0.035193  0.091803  0.079254  1.000000
# Gears          0.063831 -0.005629  0.014890  0.209642  0.014732 -0.160101
# Quarterly_Tax  0.211508 -0.193319  0.283312 -0.302287  0.305982  0.107353
# Weight         0.575869 -0.466484 -0.023969  0.087143  0.335077  0.301734
#
#                   Gears  Quarterly_Tax    Weight
# Price          0.063831       0.211508  0.575869
# Age           -0.005629      -0.193319 -0.466484
# KM             0.014890       0.283312 -0.023969
# ...

# %% [markdown]
# **EDA and Data Visualization**

# %%
import seaborn as sns

import matplotlib.pyplot as plt

# %%
sns.heatmap(df.corr(), annot=True, cmap='Blues')
# Out:
# <Axes: >

# %%
sns.pairplot(df)

# %% [markdown]
# **Model Building**

# %%
import statsmodels.formula.api as smf

import numpy as np

# %%
model=smf.ols('Price~Age+KM+HP+CC+Doors+Gears+Quarterly_Tax+Weight',data=df).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.863
# Model:                            OLS   Adj. R-squared:                  0.862
# Method:                 Least Squares   F-statistic:                     1118.
# Date:                Wed, 05 Jul 2023   Prob (F-statistic):               0.00
# Time:                        18:12:32   Log-Likelihood:                -12366.
# No. Observations:                1435   AIC:                         2.475e+04
# Df Residuals:                    1426   BIC:                         2.480e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %% [markdown]
# We can see that the variable 'CC' and 'Doors' does not accept the p-value. So they both are correlated.

# %% [markdown]
# **Collinearity Check**

# %%
rsq_Age=smf.ols('Age~KM+HP+CC+Doors+Gears+Quarterly_Tax+Weight',data=df).fit().rsquared
vif_Age=1/(1-rsq_Age)

rsq_KM=smf.ols('KM~Age+HP+CC+Doors+Gears+Quarterly_Tax+Weight',data=df).fit().rsquared
vif_KM=1/(1-rsq_KM)

rsq_HP=smf.ols('HP~Age+KM+CC+Doors+Gears+Quarterly_Tax+Weight',data=df).fit().rsquared
vif_HP=1/(1-rsq_HP)

rsq_CC=smf.ols('CC~Age+KM+HP+Doors+Gears+Quarterly_Tax+Weight',data=df).fit().rsquared
vif_CC=1/(1-rsq_CC)

rsq_Doors=smf.ols('Doors~Age+KM+HP+CC+Gears+Quarterly_Tax+Weight',data=df).fit().rsquared
vif_Doors=1/(1-rsq_Doors)

rsq_Gears=smf.ols('Gears~Age+KM+HP+CC+Doors+Quarterly_Tax+Weight',data=df).fit().rsquared
vif_Gears=1/(1-rsq_Gears)

rsq_Quarterly_Tax=smf.ols('Quarterly_Tax~Age+KM+HP+CC+Doors+Gears+Weight',data=df).fit().rsquared
vif_Quarterly_Tax=1/(1-rsq_Quarterly_Tax)

rsq_Weight=smf.ols('Weight~Age+KM+HP+CC+Doors+Gears+Quarterly_Tax',data=df).fit().rsquared
vif_Weight=1/(1-rsq_Weight)

# %%
data={'Variables':['Age','KM','HP','CC','Doors','Gears','Quarterly_Tax','Weight'],
    'Vif':[vif_Age,vif_KM,vif_HP,vif_CC,vif_Doors,vif_Gears,vif_Quarterly_Tax,vif_Weight]}
VIF_df=pd.DataFrame(data)
VIF_df
# Out:
#        Variables       Vif
# 0            Age  1.876236
# 1             KM  1.757178
# 2             HP  1.419180
# 3             CC  1.163470
# 4          Doors  1.155890
# 5          Gears  1.098843
# 6  Quarterly_Tax  2.295375
# 7         Weight  2.487180

# %% [markdown]
# **Q_Q Plot of Residual**

# %%
import statsmodels.api as sm
qqplot=sm.qqplot(model.resid,line='q')
plt.title("Normal Q-Q plot of residuals")
plt.show()

# %% [markdown]
# **Model Improvement**
#
# 1. High Influence Points.

# %%
df.shape
# Out:
# (1435, 9)

# %%
k=df.shape[1]
n=df.shape[0]
leverage_cutoff = (3*(k+1))/n
leverage_cutoff
# Out:
# 0.020905923344947737

# %%
from statsmodels.graphics.regressionplots import influence_plot
influence_plot(model)
plt.show()

# %% [markdown]
# 2. Cook's Distance

# %%
model_influence = model.get_influence()
(c, _) = model_influence.cooks_distance

# %%
fig = plt.subplots(figsize=(20, 9))
plt.stem(np.arange(len(df)), np.round(c, 3))
plt.xlabel('Row index')
plt.ylabel('Cooks Distance')
plt.show()

# %%
df[df.index.isin([80,959,220])]
# Out:
#      Price  Age     KM   HP     CC  Doors  Gears  Quarterly_Tax  Weight
# 80   18950   25  20019  110  16000      5      5            100    1180
# 220  12450   44  74172  110   1600      5      5            163    1615
# 959   9390   66  50806   86   1300      3      5             19    1480

# %%
df_new=df.drop(df.index[[80,959,220,600]],axis=0).reset_index(drop=True)
df_new
# Out:
#       Price  Age     KM   HP    CC  Doors  Gears  Quarterly_Tax  Weight
# 0     13500   23  46986   90  2000      3      5            210    1165
# 1     13750   23  72937   90  2000      3      5            210    1165
# 2     13950   24  41711   90  2000      3      5            210    1165
# 3     14950   26  48000   90  2000      3      5            210    1165
# 4     13750   30  38500   90  2000      3      5            210    1170
# ...     ...  ...    ...  ...   ...    ...    ...            ...     ...
# 1426   7500   69  20544   86  1300      3      5             69    1025
# 1427  10845   72  19000   86  1300      3      5             69    1015
# 1428   8500   71  17016   86  1300      3      5             69    1015
# 1429   7250   70  16916   86  1300      3      5             69    1015
# 1430   6950   76      1  110  1600      5      5             19    1114
#
# [1431 rows x 9 columns]

# %% [markdown]
# **Final Model**

# %%
new_model=smf.ols('Price~Age+KM+HP+CC+Doors+Gears+Quarterly_Tax+Weight',data=df_new).fit()

# %%
new_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.888
# Model:                            OLS   Adj. R-squared:                  0.888
# Method:                 Least Squares   F-statistic:                     1413.
# Date:                Wed, 05 Jul 2023   Prob (F-statistic):               0.00
# Time:                        18:12:38   Log-Likelihood:                -12182.
# No. Observations:                1431   AIC:                         2.438e+04
# Df Residuals:                    1422   BIC:                         2.443e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %% [markdown]
# After doing all possible tranformation, the **new_model** give the best R-squared value (88.8%) and have p-values less than 0.05.
